# %% [markdown]
# # TripAdvisor restaurants info

# %% [markdown]
# https://www.tripadvisor.fr/Restaurants-g274772-Krakow_Lesser_Poland_Province_Southern_Poland.html#EATERY_OVERVIEW_BOX

# %% [markdown]
# ## Scrape data from the summary list of restaurants

# %% [markdown]
# The TripAdvisor URL to scroll through the restaurants list is built as follow:
# https://www.tripadvisor.com/RestaurantSearch-g1225481-oa15, where
# - g122548 is the id of the city
# - oa30 is the variable to scroll through the pages, by incrementing by 30 to go to the next page.
#
# Restaurants are sorted by descending Ranking

# %%
#! /usr/bin/env python3
# coding: utf-8

"""
===========================
Takes a city as an argument and scrape the
summary data of each restaurants of the city
through the TA restaurants display pages
===================================================================== """

import requests
from bs4 import BeautifulSoup
import datetime
import pandas as pd
import numpy as np
import logging

#Variables that will be used globally through the script
url0 = 'https://www.tripadvisor.com'
today = datetime.datetime.now()
today_date = str(today.year) + '/' + str(today.month) + '/' + str(today.day)

#Enable display of info messages
logging.basicConfig(level=logging.INFO)

# %%
def scraper(city):
    query = '/TypeAheadJson?action=API&startTime='+today_date+'&uiOrigin=GEOSCOPE&source=GEOSCOPE&interleaved=true&type=geo&neighborhood_geos=true&link_type=eat&details=true&max=12&injectNeighborhoods=true&query='+city
    url = url0 + query
    #Query the API ad get a JSON answer readable by Python as dictionnaries objects
    api_response = requests.get(url).json()
    geo = api_response['results'][0]['url']  #Get the URL from the results/1st element/Url key
    restaurants_url = url0 + geo
    logging.info("Scraping {} restaurants info".format(city))
    print(restaurants_url)

    #Prepare the scrolling requests using a URL such as
    #https://www.tripadvisor.com/RestaurantSearch-g1225481-oa15
    scroll_url0= 'https://www.tripadvisor.com/RestaurantSearch-'
    b = restaurants_url.find('-')
    e = restaurants_url.find('-', b+1)
    city_id = restaurants_url[b+1:e]
    
    #Initialize the lists of parameters to scrape and the dataframe containing all data
    inc_page=0
    resto_dict = {}
    dataset = pd.DataFrame(resto_dict)
    #columns=['Name', 'URL_TA', 'ID_TA', 'Rating', 'Ranking', 'Price Range', 'Cuisine Style', 'Number of Reviews', 'Reviews'])
    
    #Get the total number of pages
    r = requests.get(scroll_url0+city_id,
                     headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',},
                     cookies= {"SetCurrency":"EUR"})
    soup = BeautifulSoup(r.text, "lxml")
    page_tag = soup.find_all(class_="pageNumbers")[0] #tag that displays number of pages at bottom of webpage
    a_tags = page_tag.find_all('a')  #last item of the returned list is the last page button
    tot_pages=int(a_tags[-1].contents[0])  #integer from text content of the <a>
    logging.info("{} pages to explore".format(tot_pages))
    
    #Explore all the pages that display restaurants
    for page_index in range (1, tot_pages+1):
        
        #URL of the current webpage
        scroll_url = scroll_url0 + city_id + '-oa' + str(inc_page)
        print("Scraping page n°{}".format(page_index))
        print(scroll_url)

        #Scrape HTML content of the current webpage using the library BeautifulSoup
        r = requests.get(scroll_url,
                 headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',},
                cookies= {"SetCurrency":"EUR"})
        soup = BeautifulSoup(r.text, "lxml")


        #Restaurants list starts with tag <div id="EATERY_SEARCH_RESULTS">
        data_bloc = soup.find_all(attrs={"id": "EATERY_SEARCH_RESULTS"}) #contains the data bloc in a list object
        data_bloc = data_bloc[0]  #easier to manipulate

    #First restaurant of page has a particular class attribute
        if data_bloc.find_all(class_="listing rebrand listingIndex-1 first") != []:
            resto_soup = data_bloc.find_all(class_="listing rebrand listingIndex-1 first")[0]
        else:
            resto_soup = data_bloc.find_all(class_="listing rebrand first")[0]

        #Get the url, id and name of restaurants
        url_name_tag = resto_soup.find_all(class_="property_title")[0] #tag containing the data
        #Get restaurant URL
        resto_dict['URL_TA'] = url_name_tag.get('href')
        #Get the restaurant ID within its URL (-dxxxxxxx-Reviews)
        b = url_name_tag.get('href').find('-d')
        e= url_name_tag.get('href').find('-R')
        resto_dict['ID_TA'] = url_name_tag.get('href')[b+1:e]
        #Get names
        resto_dict['Name'] = url_name_tag.contents[0][1:-1]

        #Get the ranking of the restaurant
        if resto_soup.find_all(class_="popIndex rebrand popIndexDefault") != []:
            ranking_tag = resto_soup.find_all(class_="popIndex rebrand popIndexDefault")[0]
            resto_dict['Ranking'] = ranking_tag.contents[0][1:-1]
        else:
            resto_dict['Ranking'] = np.nan #put a NaN instead

        #Get the rating of the restaurant from <span> tags
        if resto_soup.find_all('span') != []:
            span_tags = resto_soup.find_all('span')
            for tag in span_tags:
                if tag.get('alt') is not None:
                    resto_dict['Rating'] = tag.get('alt')
        else:
            resto_dict['Rating'] = np.nan

        #Information from <div class="cuisines">  
        #!! some resaurants don't have pricerange nor cuisine styles, instead <div class="cuisine_margin">
        cuisines_tags = resto_soup.find_all(class_="cuisines") #1 element of the list is 1 restaurant
        if resto_soup.find_all(class_="cuisines") != []:
            for item in cuisines_tags:
                #Get price range from <span class="item price">
                if item.find(class_="item price") is not None:
                    price_range = item.find(class_="item price") #unique tag with price range
                    resto_dict['Price Range'] = price_range.contents[0]
                else:
                     resto_dict['Price Range'] = np.nan
                #Get cuisine styles from <span class="item cuisine"> tags (several/restaurant)
                if item.find_all(class_="item cuisine") != []:
                    cuisines = item.find_all(class_="item cuisine")  # list of <a> tags with the cuisine style as text
                    resto_dict['Cuisine Style'] = [tag.contents[0] for tag in cuisines]
                else:
                    resto_dict['Cuisine Style'] = np.nan

        #Get number of reviews
        if resto_soup.find_all(class_="reviewCount") != []:
            numb_tag = resto_soup.find_all(class_="reviewCount")[0]
            resto_dict['Number of Reviews'] = numb_tag.find('a').contents[0][1:-9]
        else:
            resto_dict['Number of Reviews'] = np.nan
            
        #Get 2 reviews (text+date) from <ul class="review_stubs review_snippets rebrand"> and <li> tags within
        ul_tags = resto_soup.find_all(class_="review_stubs review_snippets rebrand")
        if ul_tags != []:
            for reviews_set in ul_tags:
                rev_texts = reviews_set.find_all(dir="ltr")
                rev_dates = reviews_set.find_all(class_="date")
                resto_dict['Reviews'] = [[tag.find('a').contents[0] for tag in rev_texts], #text is in a <a> tag
                                          [tag.contents[0] for tag in rev_dates]]
        else:
            resto_dict['Reviews'] = np.nan
            
        #Append the dataset
        dataset = pd.concat([dataset, pd.DataFrame([resto_dict])])
            
    #For the rest of the list from 2 to 30:
        try:
            inc_rest = 0
            for i in range (2, 31):
                resto_dict = {}
                resto_bloc_id = "listing rebrand listingIndex-" + str(i)
                if data_bloc.find_all(class_=resto_bloc_id) != []:
                    resto_soup = data_bloc.find_all(class_=resto_bloc_id)[0] #Bloc for one restaurant

                    #Get the url, id and name of restaurants
                    url_name_tag = resto_soup.find_all(class_="property_title")[0] #tag containing the data
                    #Get restaurant URL
                    resto_dict['URL_TA'] = url_name_tag.get('href')
                    #Get the restaurant ID within its URL (-dxxxxxxx-Reviews)
                    b = url_name_tag.get('href').find('-d')
                    e= url_name_tag.get('href').find('-R')
                    resto_dict['ID_TA'] = url_name_tag.get('href')[b+1:e]
                    #Get names
                    resto_dict['Name'] = url_name_tag.contents[0][1:-1]

                    #Get the ranking of the restaurant
                    if resto_soup.find_all(class_="popIndex rebrand popIndexDefault") != []:
                        ranking_tag = resto_soup.find_all(class_="popIndex rebrand popIndexDefault")[0]
                        resto_dict['Ranking'] = ranking_tag.contents[0][1:-1]
                    else:
                        resto_dict['Ranking'] = np.nan

                    #Get the rating of the restaurant from <span> tags
                    span_tags = resto_soup.find_all('span')
                    if resto_soup.find_all('span') != []:
                        for tag in span_tags:
                            if tag.get('alt') is not None:
                                resto_dict['Rating'] = tag.get('alt')
                    else:
                        resto_dict['Rating'] = np.nan

                    #Information from <div class="cuisines">  
                    #!! some resaurants don't have pricerange nor cuisine styles, instead <div class="cuisine_margin">
                    cuisines_tags = resto_soup.find_all(class_="cuisines") #1 element of the list is 1 restaurant
                    if resto_soup.find_all(class_="cuisines") != []:
                        for item in cuisines_tags:
                            #Get price range from <span class="item price">
                            if item.find(class_="item price") is not None:
                                price_range = item.find(class_="item price") #unique tag with price range
                                resto_dict['Price Range'] = price_range.contents[0]
                            else:
                                resto_dict['Price Range'] = np.nan
                            #Get cuisine styles from <span class="item cuisine"> tags (several/restaurant)
                            if item.find_all(class_="item cuisine") != []:
                                cuisines = item.find_all(class_="item cuisine")  # list of <a> tags with the cuisine style as text
                                resto_dict['Cuisine Style'] = [tag.contents[0] for tag in cuisines]
                            else: 
                                resto_dict['Cuisine Style'] = np.nan

                    #Get number of reviews
                    if resto_soup.find_all(class_="reviewCount") != []:
                        numb_tag = resto_soup.find_all(class_="reviewCount")[0]
                        resto_dict['Number of Reviews'] = numb_tag.find('a').contents[0][1:-9]
                    else:
                        resto_dict['Number of Reviews'] = np.nan

                    #Get 2 reviews (text+date) from <ul class="review_stubs review_snippets rebrand"> and <li> tags within
                    ul_tags = resto_soup.find_all(class_="review_stubs review_snippets rebrand")
                    if resto_soup.find_all(class_="review_stubs review_snippets rebrand") != []:
                        for reviews_set in ul_tags:
                            rev_texts = reviews_set.find_all(dir="ltr")
                            rev_dates = reviews_set.find_all(class_="date")
                            resto_dict['Reviews'] = [[tag.find('a').contents[0] for tag in rev_texts], #text is in a <a> tag
                                                  [tag.contents[0] for tag in rev_dates]]
                    else:
                        resto_dict['Reviews'] = np.nan
                    
                    #Append the dataset
                    dataset = pd.concat([dataset, pd.DataFrame([resto_dict])])
                        
                else: #tag of restaurant is instead "listing rebrand"
                    resto_soup = data_bloc.find_all(class_="listing rebrand")[inc_rest]
                    
                    #Get the url, id and name of restaurants
                    url_name_tag = resto_soup.find_all(class_="property_title")[0] #tag containing the data
                    #Get restaurant URL
                    resto_dict['URL_TA'] = url_name_tag.get('href')
                    #Get the restaurant ID within its URL (-dxxxxxxx-Reviews)
                    b = url_name_tag.get('href').find('-d')
                    e= url_name_tag.get('href').find('-R')
                    resto_dict['ID_TA'] = url_name_tag.get('href')[b+1:e]
                    #Get names
                    resto_dict['Name'] = url_name_tag.contents[0][1:-1]

                    #Get the ranking of the restaurant
                    if resto_soup.find_all(class_="popIndex rebrand popIndexDefault") != []:
                        ranking_tag = resto_soup.find_all(class_="popIndex rebrand popIndexDefault")[0]
                        resto_dict['Ranking'] = ranking_tag.contents[0][1:-1]
                    else:
                        resto_dict['Ranking'] = np.nan

                    #Get the rating of the restaurant from <span> tags
                    span_tags = resto_soup.find_all('span')
                    if resto_soup.find_all('span') != []:
                        for tag in span_tags:
                            if tag.get('alt') is not None:
                                resto_dict['Rating'] = tag.get('alt')
                    else:
                        resto_dict['Rating'] = np.nan

                    #Information from <div class="cuisines">  
                    #!! some resaurants don't have pricerange nor cuisine styles, instead <div class="cuisine_margin">
                    cuisines_tags = resto_soup.find_all(class_="cuisines") #1 element of the list is 1 restaurant
                    if resto_soup.find_all(class_="cuisines") != []:
                        for item in cuisines_tags:
                            #Get price range from <span class="item price">
                            if item.find(class_="item price") is not None:
                                price_range = item.find(class_="item price") #unique tag with price range
                                resto_dict['Price Range'] = price_range.contents[0]
                            else:
                                resto_dict['Price Range'] = np.nan
                            #Get cuisine styles from <span class="item cuisine"> tags (several/restaurant)
                            if item.find_all(class_="item cuisine") != []:
                                cuisines = item.find_all(class_="item cuisine")  # list of <a> tags with the cuisine style as text
                                resto_dict['Cuisine Style'] = [tag.contents[0] for tag in cuisines]
                            else: 
                                resto_dict['Cuisine Style'] = np.nan

                    #Get number of reviews
                    if resto_soup.find_all(class_="reviewCount") != []:
                        numb_tag = resto_soup.find_all(class_="reviewCount")[0]
                        resto_dict['Number of Reviews'] = numb_tag.find('a').contents[0][1:-9]
                    else:
                        resto_dict['Number of Reviews'] = np.nan

                    #Get 2 reviews (text+date) from <ul class="review_stubs review_snippets rebrand"> and <li> tags within
                    ul_tags = resto_soup.find_all(class_="review_stubs review_snippets rebrand")
                    if resto_soup.find_all(class_="review_stubs review_snippets rebrand") != []:
                        for reviews_set in ul_tags:
                            rev_texts = reviews_set.find_all(dir="ltr")
                            rev_dates = reviews_set.find_all(class_="date")
                            resto_dict['Reviews'] = [[tag.find('a').contents[0] for tag in rev_texts], #text is in a <a> tag
                                                  [tag.contents[0] for tag in rev_dates]]
                    else:
                        resto_dict['Reviews'] = np.nan
                    
                    #Append the dataset
                    dataset = pd.concat([dataset, pd.DataFrame([resto_dict])])
                    
                    inc_rest += 1
                
            #Increment to next page to display the next 30 restaurants
            inc_page += 30
    
        except IndexError:
            logging.info("Last restaurant reached")
            break
    
    #Save dataframe as csv file
    dataset.to_csv(city + '_TA_restaurants_raw.csv', sep=',', encoding="utf-8")
    print("File created in current directory: {}_TA_restaurants_raw.csv".format(city))

    return(dataset)

# %%
scraper('Krakow')
# Out:
# https://www.tripadvisor.com/Restaurants-g274772-Krakow_Lesser_Poland_Province_Southern_Poland.html
# INFO:root:46 pages to explore
# Scraping page n°1
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa0
# Scraping page n°2
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa30
# Scraping page n°3
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa60
# Scraping page n°4
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa90
# Scraping page n°5
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa120
# Scraping page n°6
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa150
# Scraping page n°7
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa180
# Scraping page n°8
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa210
# Scraping page n°9
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa240
# Scraping page n°10
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa270
# Scraping page n°11
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa300
# Scraping page n°12
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa330
# Scraping page n°13
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa360
# Scraping page n°14
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa390
# Scraping page n°15
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa420
# Scraping page n°16
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa450
# Scraping page n°17
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa480
# Scraping page n°18
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa510
# Scraping page n°19
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa540
# Scraping page n°20
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa570
# Scraping page n°21
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa600
# Scraping page n°22
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa630
# Scraping page n°23
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa660
# Scraping page n°24
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa690
# Scraping page n°25
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa720
# Scraping page n°26
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa750
# Scraping page n°27
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa780
# Scraping page n°28
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa810
# Scraping page n°29
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa840
# Scraping page n°30
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa870
# Scraping page n°31
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa900
# Scraping page n°32
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa930
# Scraping page n°33
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa960
# Scraping page n°34
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa990
# Scraping page n°35
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1020
# Scraping page n°36
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1050
# Scraping page n°37
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1080
# Scraping page n°38
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1110
# Scraping page n°39
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1140
# Scraping page n°40
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1170
# Scraping page n°41
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1200
# Scraping page n°42
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1230
# Scraping page n°43
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1260
# Scraping page n°44
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1290
# Scraping page n°45
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1320
# Scraping page n°46
# https://www.tripadvisor.com/RestaurantSearch-g274772-oa1350
# INFO:root:Last restaurant reached
# File created in current directory: Krakow_TA_restaurants_raw.csv
#                                         Cuisine Style      ID_TA  \
# 0   [Polish, Cafe, European, Vegetarian Friendly, ...  d10086671
# 0   [European, Polish, Eastern European, Central E...   d8412137
# 0   [Japanese, Sushi, Asian, Fusion, Vegetarian Fr...  d11812564
# 0   [Diner, Fast Food, Healthy, Vegetarian Friendl...   d8868480
# 0   [Polish, Eastern European, Central European, V...   d1749958
# 0   [Polish, European, Eastern European, Central E...   d3172567
# 0   [Polish, Eastern European, Central European, V...   d3222026
# 0   [Contemporary, Fusion, Healthy, Polish, Europe...   d1965370
# 0   [Italian, European, Vegetarian Friendly, Vegan...   d6782602
# 0   [Japanese, Seafood, Sushi, Asian, Vegetarian F...   d8813838
# 0                                               [Pub]   d5506810
# 0   [Indian, Asian, Vegetarian Friendly, Vegan Opt...  d11756832
# 0   [Mediterranean, Polish, International, Europea...   d9739296
# 0   [Italian, Pizza, Mediterranean, European, Vege...  d12091786
# 0   [Italian, Polish, Healthy, Wine Bar, Vegetaria...   d8141152
# 0   [Polish, International, European, Vegetarian F...   d5582351
# 0   [Polish, European, Central European, Internati...   d4847400
# 0   [Polish, European, Eastern European, Central E...   d5953938
# 0   [Polish, European, Central European, Vegetaria...   d8683146
# 0   [French, European, Central European, Vegetaria...    d693568
# 0   [Polish, Central European, Vegetarian Friendly...  d10597766
# 0                            [Italian, American, Bar]   d2067708
# 0   [Polish, European, Eastern European, Central E...   d1051520
# 0   [Italian, Polish, Mediterranean, European, Cen...   d2369590
# 0   [Polish, European, Vegetarian Friendly, Gluten...   d2419699
# 0   [Italian, Seafood, Mediterranean, European, Ve...    d697084
# 0   [Polish, European, Eastern European, Israeli, ...   d2492103
# 0   [Seafood, French, Mediterranean, European, Veg...   d4753599
# 0   [Polish, European, Eastern European, Vegetaria...   d3573518
# 0   [New Zealand, Bar, Fast Food, Vegetarian Frien...   d2275248
# ..                                                ...        ...
# 0                [Pizza, Healthy, Street Food, Soups]  d12819480
# 0                                  [Polish, European]  d12820557
# 0                                           [Italian]  d12826448
# 0                                           [Italian]  d12826473
# 0                                           [Italian]  d12832990
# 0                                              [Cafe]  d12842610
# 0                       [Polish, Fast Food, European]  d12918579
# 0                        [American, Polish, European]  d12956944
# 0                                              [Cafe]  d13007149
# 0     [Polish, European, Eastern European, Ukrainian]  d13007860
# 0                                              [Thai]  d13094501
# 0                  [Italian, Polish, European, Diner]  d13094962
# 0                            [Polish, Cafe, European]  d13110342
# 0   [Polish, International, European, Fusion, Cent...  d13110367
# 0                                  [Polish, European]  d13121016
# 0                     [French, Indian, Asian, Fusion]  d13133451
# 0   [Fast Food, Cafe, Pub, Healthy, Eastern Europe...  d13134319
# 0                                              [Cafe]  d13165354
# 0                                [Asian, Bangladeshi]  d13189620
# 0                        [American, Polish, European]  d13189905
# 0                            [Polish, Cafe, European]  d13219694
# 0    [French, Cafe, International, European, Healthy]  d13219829
# 0                  [Italian, Mediterranean, European]  d13318872
# 0            [Turkish, Grill, Middle Eastern, Arabic]  d13323617
# 0                            [Italian, Mediterranean]  d13323705
# 0                                          [European]  d13337017
# 0                                  [Polish, European]  d13337153
# 0                                  [Polish, European]  d13340587
# 0                                           [Italian]  d13340639
# 0                                          [Bar, Pub]  d13345651
#
#                               Name Number of Reviews Price Range  \
# 0                      Gossip Cafe               169    $$ - $$$
# 0   Old Town Restaurant Wine & Bar             1,091    $$ - $$$
# 0                Nago Sushi & Sake               326        $$$$
# 0                            Vegab               555           $
# 0               Restauracja Starka             4,476    $$ - $$$
# 0           Przystanek Pierogarnia               589           $
# 0                Trezo Restauracja             2,081    $$ - $$$
# 0                  Zielona Kuchnia             1,043    $$ - $$$
# 0                           Bianca             1,347    $$ - $$$
# 0                    Youmiko Sushi               544    $$ - $$$
# 0                 Dobry Kumpel Pub               202    $$ - $$$
# 0                   Taste of India               374    $$ - $$$
# 0      Albertina Restaurant & Wine               321        $$$$
# 0                       Fiorentina               284    $$ - $$$
# 0          Sissi Restaurant & Wine               623    $$ - $$$
# 0            Introligatornia Smaku             1,804    $$ - $$$
# 0                       FAB Fusion               590    $$ - $$$
# 0     Czarna Kaczka The Black Duck             1,658    $$ - $$$
# 0                Qrudo Food & Wine               384    $$ - $$$
# 0               Cyrano de Bergerac             1,247        $$$$
# 0                        Szara Ges               413        $$$$
# 0              Movida Cocktail Bar               480    $$ - $$$
# 0                 Klimaty Poludnia               675    $$ - $$$
# 0                Restauracja Padre               759    $$ - $$$
# 0              Amarylis Restaurant               426        $$$$
# 0                      Aqua e Vino               879    $$ - $$$
# 0                 Once Upon a Time               332    $$ - $$$
# 0                            Corse               546    $$ - $$$
# 0                  Milkbar Tomasza             1,412           $
# 0                        Moaburger             1,713           $
# ..                             ...               ...         ...
# 0                          ZuPizza               NaN           $
# 0                     Point Frappe               NaN           $
# 0                          AMORINO               NaN           $
# 0                Gelateria Vicenti               NaN           $
# 0                         iL PEZZO               NaN           $
# 0                    Deli Sandwich               NaN           $
# 0                  Red Grill House               NaN         NaN
# 0                  Cyrk na Kolkach               NaN           $
# 0           Massolit Bakery & Cafe               NaN         NaN
# 0                    Kuchnia Billi               NaN           $
# 0              Frozen Rolls Polska               NaN           $
# 0                   Miedzy Daniami               NaN           $
# 0            Piekarnia Mojego Taty               NaN         NaN
# 0               METRUM Restobistro               NaN    $$ - $$$
# 0    Lady's FOOD TRUCK - nalesniki               NaN           $
# 0                         Oh Crepe               NaN           $
# 0     What’s up Krakow. Social pub               NaN           $
# 0                         Klubczyk               NaN         NaN
# 0                Coffeece Mogilska               NaN           $
# 0                       Huta Smaku               NaN           $
# 0                         Lajkonik               NaN         NaN
# 0                OGGI Urban Bistro               NaN           $
# 0                        Per Tutti               NaN           $
# 0                          Kebaber               NaN           $
# 0                        Per Tutti               NaN           $
# 0            Urban Coffee and more               NaN           $
# 0                  Blekitna Laguna               NaN           $
# 0                  kwadrans Bistro               NaN         NaN
# 0                Pizzeria Al Forno               NaN         NaN
# 0   Kawiarnia Teatralna w Krakowie               NaN           $
#
#                                Ranking            Rating  \
# 0    #1 of 1,351 Restaurants in Krakow    5 of 5 bubbles
# 0    #2 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0    #3 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0    #4 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0    #5 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0    #6 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0    #7 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0    #8 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0    #9 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #10 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #11 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #12 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #13 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #14 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #15 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #16 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #17 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #18 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #19 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #20 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #21 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #22 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #23 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #24 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #25 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #26 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #27 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #28 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #29 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# 0   #30 of 1,351 Restaurants in Krakow  4.5 of 5 bubbles
# ..                                 ...               ...
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
# 0                                  NaN               NaN
#
#                                               Reviews  \
# 0   [[Delicious breakfast, Very good], [01/08/2018...
# 0   [[Faultless, Brilliant food at fantastic price...
# 0   [[Great atmosphere, Best I have ever been to!]...
# 0   [[Coming back to Krakow just for a Kebab her.....
# 0   [[Every bite was amazing, Excellent], [01/08/2...
# 0   [[Pyszota, Amazing food, amazing prices!!!], [...
# 0   [[A glimpse of past days, Great service and ex...
# 0   [[Superb, Best dinner in Europe], [12/31/2017,...
# 0   [[Perfect Italian in Krakow, Amazing!! Two mic...
# 0   [[Love! Meat/fish eaters try the vegan optio.....
# 0   [[Fabulous bar, Great atmosphere, New Year cel...
# 0   [[Delicious Indian, Excellent food & perfect h...
# 0   [[Something to tell your kids even when you......
# 0   [[5* service, Best experience in Krakow!], [01...
# 0   [[Lovely food!, Amazing food, warmly welcoming...
# 0   [[Incredible food/drinks & top-notch service.....
# 0   [[Good Food, Fabulous fine dining experience],...
# 0   [[Excellent restaurant - service and food!, Ex...
# 0   [[Hidden gem. Fabulous!, Nearly good enough fo...
# 0   [[Excellent Restaurant, excellent place], [01/...
# 0   [[Screaming the need of a Michelin Star!, Supe...
# 0   [[Christmas Break, Cocktails and music], [01/0...
# 0   [[Very good food and service, SPECIAL!], [01/0...
# 0   [[Nice place but main course were poorly exe.....
# 0   [[Gastronomy at no price, Great restaurant], [...
# 0   [[Sis going out, Great], [01/03/2018, 12/06/20...
# 0   [[Lovely!, Great atmosphere, great food], [01/...
# 0   [[Amazing food, low traffic, great place to......
# 0   [[Cheap, tasty and quick food, Great food at a...
# 0   [[Massive delicious burgers, Good burgers, fai...
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#                                                URL_TA
# 0   /Restaurant_Review-g274772-d10086671-Reviews-G...
# 0   /Restaurant_Review-g274772-d8412137-Reviews-Ol...
# 0   /Restaurant_Review-g274772-d11812564-Reviews-N...
# 0   /Restaurant_Review-g274772-d8868480-Reviews-Ve...
# 0   /Restaurant_Review-g274772-d1749958-Reviews-Re...
# 0   /Restaurant_Review-g274772-d3172567-Reviews-Pr...
# 0   /Restaurant_Review-g274772-d3222026-Reviews-Tr...
# 0   /Restaurant_Review-g274772-d1965370-Reviews-Zi...
# 0   /Restaurant_Review-g274772-d6782602-Reviews-Bi...
# 0   /Restaurant_Review-g274772-d8813838-Reviews-Yo...
# 0   /Restaurant_Review-g274772-d5506810-Reviews-Do...
# 0   /Restaurant_Review-g274772-d11756832-Reviews-T...
# 0   /Restaurant_Review-g274772-d9739296-Reviews-Al...
# 0   /Restaurant_Review-g274772-d12091786-Reviews-F...
# 0   /Restaurant_Review-g274772-d8141152-Reviews-Si...
# 0   /Restaurant_Review-g274772-d5582351-Reviews-In...
# 0   /Restaurant_Review-g274772-d4847400-Reviews-FA...
# 0   /Restaurant_Review-g274772-d5953938-Reviews-Cz...
# 0   /Restaurant_Review-g274772-d8683146-Reviews-Qr...
# 0   /Restaurant_Review-g274772-d693568-Reviews-Cyr...
# 0   /Restaurant_Review-g274772-d10597766-Reviews-S...
# 0   /Restaurant_Review-g274772-d2067708-Reviews-Mo...
# 0   /Restaurant_Review-g274772-d1051520-Reviews-Kl...
# 0   /Restaurant_Review-g274772-d2369590-Reviews-Re...
# 0   /Restaurant_Review-g274772-d2419699-Reviews-Am...
# 0   /Restaurant_Review-g274772-d697084-Reviews-Aqu...
# 0   /Restaurant_Review-g274772-d2492103-Reviews-On...
# 0   /Restaurant_Review-g274772-d4753599-Reviews-Co...
# 0   /Restaurant_Review-g274772-d3573518-Reviews-Mi...
# 0   /Restaurant_Review-g274772-d2275248-Reviews-Mo...
# ..                                                ...
# 0   /Restaurant_Review-g274772-d12819480-Reviews-Z...
# 0   /Restaurant_Review-g274772-d12820557-Reviews-P...
# 0   /Restaurant_Review-g274772-d12826448-Reviews-A...
# 0   /Restaurant_Review-g274772-d12826473-Reviews-G...
# 0   /Restaurant_Review-g274772-d12832990-Reviews-I...
# 0   /Restaurant_Review-g274772-d12842610-Reviews-D...
# 0   /Restaurant_Review-g274772-d12918579-Reviews-R...
# 0   /Restaurant_Review-g274772-d12956944-Reviews-C...
# 0   /Restaurant_Review-g274772-d13007149-Reviews-M...
# 0   /Restaurant_Review-g274772-d13007860-Reviews-K...
# 0   /Restaurant_Review-g274772-d13094501-Reviews-F...
# 0   /Restaurant_Review-g274772-d13094962-Reviews-M...
# 0   /Restaurant_Review-g274772-d13110342-Reviews-P...
# 0   /Restaurant_Review-g274772-d13110367-Reviews-M...
# 0   /Restaurant_Review-g274772-d13121016-Reviews-L...
# 0   /Restaurant_Review-g274772-d13133451-Reviews-O...
# 0   /Restaurant_Review-g274772-d13134319-Reviews-W...
# 0   /Restaurant_Review-g274772-d13165354-Reviews-K...
# 0   /Restaurant_Review-g274772-d13189620-Reviews-C...
# 0   /Restaurant_Review-g274772-d13189905-Reviews-H...
# 0   /Restaurant_Review-g274772-d13219694-Reviews-L...
# 0   /Restaurant_Review-g274772-d13219829-Reviews-O...
# 0   /Restaurant_Review-g274772-d13318872-Reviews-P...
# 0   /Restaurant_Review-g274772-d13323617-Reviews-K...
# 0   /Restaurant_Review-g274772-d13323705-Reviews-P...
# 0   /Restaurant_Review-g274772-d13337017-Reviews-U...
# 0   /Restaurant_Review-g274772-d13337153-Reviews-B...
# 0   /Restaurant_Review-g274772-d13340587-Reviews-K...
# 0   /Restaurant_Review-g274772-d13340639-Reviews-P...
# 0   /Restaurant_Review-g274772-d13345651-Reviews-K...
#
# [1351 rows x 9 columns]

# %%
euro_capitals = ['Paris', 'London', 'Budapest', 'Madrid', 'Lisbon', 'Berlin', 'Rome', 
            'Athens', 'Vienna', 'Warsaw', 'Ljubljana', 'Dublin',
                 'Bruxelles', 'Prague', 'Amsterdam', 'Luxembourg', 'Bratislava',
                'Copenhagen', 'Oslo', 'Helsinki', 'Stockholm']
#Paris London and Budapest already scraped
for city in euro_capitals[4:]:
    scraper(city)
# Out:
# INFO:root:Scraping Lisbon restaurants info
# https://www.tripadvisor.com/Restaurants-g189158-Lisbon_Lisbon_District_Central_Portugal.html
# INFO:root:139 pages to explore
# Scraping page n°1
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa0
# Scraping page n°2
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa30
# Scraping page n°3
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa60
# Scraping page n°4
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa90
# Scraping page n°5
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa120
# Scraping page n°6
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa150
# Scraping page n°7
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa180
# Scraping page n°8
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa210
# Scraping page n°9
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa240
# Scraping page n°10
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa270
# Scraping page n°11
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa300
# Scraping page n°12
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa330
# Scraping page n°13
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa360
# Scraping page n°14
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa390
# Scraping page n°15
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa420
# Scraping page n°16
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa450
# Scraping page n°17
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa480
# Scraping page n°18
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa510
# Scraping page n°19
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa540
# Scraping page n°20
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa570
# Scraping page n°21
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa600
# Scraping page n°22
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa630
# Scraping page n°23
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa660
# Scraping page n°24
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa690
# Scraping page n°25
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa720
# Scraping page n°26
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa750
# Scraping page n°27
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa780
# Scraping page n°28
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa810
# Scraping page n°29
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa840
# Scraping page n°30
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa870
# Scraping page n°31
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa900
# Scraping page n°32
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa930
# Scraping page n°33
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa960
# Scraping page n°34
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa990
# Scraping page n°35
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1020
# Scraping page n°36
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1050
# Scraping page n°37
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1080
# Scraping page n°38
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1110
# Scraping page n°39
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1140
# Scraping page n°40
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1170
# Scraping page n°41
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1200
# Scraping page n°42
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1230
# Scraping page n°43
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1260
# Scraping page n°44
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1290
# Scraping page n°45
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1320
# Scraping page n°46
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1350
# Scraping page n°47
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1380
# Scraping page n°48
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1410
# Scraping page n°49
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1440
# Scraping page n°50
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1470
# Scraping page n°51
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1500
# Scraping page n°52
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1530
# Scraping page n°53
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1560
# Scraping page n°54
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1590
# Scraping page n°55
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1620
# Scraping page n°56
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1650
# Scraping page n°57
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1680
# Scraping page n°58
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1710
# Scraping page n°59
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1740
# Scraping page n°60
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1770
# Scraping page n°61
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1800
# Scraping page n°62
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1830
# Scraping page n°63
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1860
# Scraping page n°64
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1890
# Scraping page n°65
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1920
# Scraping page n°66
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1950
# Scraping page n°67
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa1980
# Scraping page n°68
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2010
# Scraping page n°69
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2040
# Scraping page n°70
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2070
# Scraping page n°71
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2100
# Scraping page n°72
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2130
# Scraping page n°73
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2160
# Scraping page n°74
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2190
# Scraping page n°75
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2220
# Scraping page n°76
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2250
# Scraping page n°77
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2280
# Scraping page n°78
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2310
# Scraping page n°79
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2340
# Scraping page n°80
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2370
# Scraping page n°81
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2400
# Scraping page n°82
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2430
# Scraping page n°83
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2460
# Scraping page n°84
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2490
# Scraping page n°85
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2520
# Scraping page n°86
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2550
# Scraping page n°87
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2580
# Scraping page n°88
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2610
# Scraping page n°89
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2640
# Scraping page n°90
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2670
# Scraping page n°91
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2700
# Scraping page n°92
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2730
# Scraping page n°93
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2760
# Scraping page n°94
# https://www.tripadvisor.com/RestaurantSearch-g189158-oa2790

# %% [markdown]
# ---
